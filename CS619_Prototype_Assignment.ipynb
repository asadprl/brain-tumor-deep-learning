# %% [markdown]
# <a href="https://colab.research.google.com/github/asadprl/brain-tumor-deep-learning/blob/main/CS619_Prototype_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#  # **Brain Tumor Detection through Transfer Learning**
# ---
# ## **Protype Phase Assignment**

# %% [markdown]
# ###**Problem Statement:**

# %% [markdown]
# The prototype involves the following steps:
#
# 1.	Collect a diverse dataset of medical images, including MRI.
# 2.	Preprocess the dataset, ensuring uniformity in terms of image size, format, and quality.
# 3.	Select pre-trained deep learning models suitable for transfer learning, such as including Visual Geometry Group 16 (VGG16), InceptionV3, VGG19, ResNet50, InceptionResNetV2, and Xception. You should select two well-established pre-trained models.

# %% [markdown]
# ###**Solution:**

# %% [markdown]
# ####**1. Dataset**

# %% [markdown]
# For this assignment I have used the MRI images dataset found on Kaggle from [this link](https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset).
# This dataset is a combination of following datasets:
# >1. [Figshare](https://figshare.com/articles/dataset/brain_tumor_dataset/1512427)
# 2. [Sartaj](https://www.kaggle.com/sartajbhuvaji/brain-tumor-classification-mri)
# 3. [BR35H](https://www.kaggle.com/datasets/ahmedhamada0/brain-tumor-detection?select=no)
#
# The Dataset contains total 7023 MRI images of human brain which are divided into 4 classes:
# >1. Glioma
# 2. Meningioma
# 3. Pituitory
# 4. Normal

# %% [markdown]
# #####**1.1 Importing Necessary Libraries and Modules**

# %%
import os
import gdown
import zipfile
from ipywidgets import interact
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.vgg19 import VGG19

# %% [markdown]
# #####**1.2 Configuration Settings**

# %%
# path to different directories
dataset_path = '/content/dataset'
train_dir = os.path.join(dataset_path, 'Training')
test_dir = os.path.join(dataset_path, 'Testing')

image_size = (224, 224)
batch_size = 32

# %% [markdown]
# #####**1.3 Downloading Dataset**
# I have stored the dataset in my gdrive so downloading the dataset to current environment. It will be saved in /content directory

# %%
dataset_url = 'https://drive.google.com/uc?id=1Rt-nwEiY9UjWcZRrRRsQS7EN129DwFwV'
dataset_file = 'brain_tumor_dataset.zip'
gdown.download(url=dataset_url, output=dataset_file)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Rt-nwEiY9UjWcZRrRRsQS7EN129DwFwV
# From (redirected): https://drive.google.com/uc?id=1Rt-nwEiY9UjWcZRrRRsQS7EN129DwFwV&confirm=t&uuid=1671cad6-591a-4936-b1c6-eaae6e6e9cb1
# To: /content/brain_tumor_dataset.zip
# 100%|██████████| 156M/156M [00:00<00:00, 208MB/s]
# 'brain_tumor_dataset.zip'

# %% [markdown]
# #####**1.4 Extracting Dataset**
# Dataset is in zip format so extracting it to dataset directory. "/content/dataset"

# %%
zip_ref = zipfile.ZipFile(dataset_file, 'r')
zip_ref.extractall(dataset_path)

# %% [markdown]
# The dataset is already divided into two subdirectories. Testing and Training. So we don't need to seperate the dataset into two subsets it is already divided and also dataset structure is compatible with keras' `flow_from_directory` method. It mean each Training and Testing subsets has subdirectories for each class like:
# - Testing
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary
# - Training
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary

# %% [markdown]
# ####**2. Preprocessing**

# %% [markdown]
# Training Data will be divided into two part, for training and validation while Testing Data will be seperate that will not be used during training. 80% data in Training directory will be used for training and remaining 20% in this directory will be used for validation purpose. Data will be loaded using keras' ImageDataGenerator. All the images will be rescaled to target size. This will ensure the uniformity in terms of image size and format. As all the images will be rescaled to required size and format realtime during the training. During training, training and validation data will be augmented realtime using datagenerator while the testing data will be remain same. Only rescaling will be applied to this data.

# %%
# ImageDataGenerator for Training and Validation
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,
                                                                validation_split=0.2)
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=image_size,
                                                    class_mode='categorical',
                                                    batch_size=batch_size,
                                                    shuffle=True,
                                                    subset='training')

val_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=image_size,
                                                    class_mode='categorical',
                                                    batch_size=batch_size,
                                                    shuffle=True,
                                                    subset='validation')

# ImageDataGenerator for Testing
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(test_dir,
                                                  target_size=image_size,
                                                  class_mode='categorical',
                                                  batch_size=batch_size)
# Out:
# Found 4571 images belonging to 4 classes.
# Found 1141 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %%
# some sample images
images, labels =  val_generator.next()

@interact(idx=(0,batch_size-1))
def display_image(idx):
  plt.imshow(images[idx])
  plt.show()
# Out:
# interactive(children=(IntSlider(value=15, description='idx', max=31), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# ####**3. Transfer Learning Models**

# %%
class PretrainedModel:
    def __init__(self):
        self.base_model = None
        self.model = None

    def load_base_model(self, model):
        self.base_model = model(
            weights = 'imagenet',
            include_top = False,
            input_shape = (image_size + (3,))
        )

    def freeze_layers(self):
        for layer in self.base_model.layers:
            layer.trainable = False
        self.base_model.trainable = False

    def create_final_model(self):
        pass

    def summary(self):
        return self.model.summary()

# %% [markdown]
# #####**3.1 InceptionV3**

# %%
class InceptionV3Model(PretrainedModel):
    def __init__(self):
        super().__init__()

    def load_base_model(self):
        super().load_base_model(InceptionV3)

    def create_final_model(self):
        self.freeze_layers()

        last_output = self.base_model.output
        x = tf.keras.layers.GlobalAveragePooling2D()(last_output)
        x = tf.keras.layers.Dense(128, activation='relu', name='new_dense_1')(x)
        x = tf.keras.layers.Dense(4, activation='softmax',name='new_output')(x)

        self.model = tf.keras.models.Model(inputs=self.base_model.input, outputs=x)

        self.model.compile(optimizer='adam', loss='categorical_crossentropy',
                  metrics=['categorical_accuracy'])

# %%
inception_model = InceptionV3Model()
inception_model.load_base_model()
inception_model.create_final_model()
inception_model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_658 (Conv2D)         (None, 111, 111, 32)         864       ['input_8[0][0]']
#
#  batch_normalization_658 (B  (None, 111, 111, 32)         96        ['conv2d_658[0][0]']
#  atchNormalization)
#
#  activation_658 (Activation  (None, 111, 111, 32)         0         ['batch_normalization_658[0][0
#  )                                                                  ]']
#
#  conv2d_659 (Conv2D)         (None, 109, 109, 32)         9216      ['activation_658[0][0]']
#
#  batch_normalization_659 (B  (None, 109, 109, 32)         96        ['conv2d_659[0][0]']
#  atchNormalization)
#
#  activation_659 (Activation  (None, 109, 109, 32)         0         ['batch_normalization_659[0][0
#  )                                                                  ]']
#
#  conv2d_660 (Conv2D)         (None, 109, 109, 64)         18432     ['activation_659[0][0]']
#
#  batch_normalization_660 (B  (None, 109, 109, 64)         192       ['conv2d_660[0][0]']
#  atchNormalization)
#
#  activation_660 (Activation  (None, 109, 109, 64)         0         ['batch_normalization_660[0][0
#  )                                                                  ]']
#
#  max_pooling2d_28 (MaxPooli  (None, 54, 54, 64)           0         ['activation_660[0][0]']
#  ng2D)
#
#  conv2d_661 (Conv2D)         (None, 54, 54, 80)           5120      ['max_pooling2d_28[0][0]']
#
#  batch_normalization_661 (B  (None, 54, 54, 80)           240       ['conv2d_661[0][0]']
#  atchNormalization)
#
#  activation_661 (Activation  (None, 54, 54, 80)           0         ['batch_normalization_661[0][0
#  )                                                                  ]']
#
#  conv2d_662 (Conv2D)         (None, 52, 52, 192)          138240    ['activation_661[0][0]']
#
#  batch_normalization_662 (B  (None, 52, 52, 192)          576       ['conv2d_662[0][0]']
#  atchNormalization)
#
#  activation_662 (Activation  (None, 52, 52, 192)          0         ['batch_normalization_662[0][0
#  )                                                                  ]']
#
#  max_pooling2d_29 (MaxPooli  (None, 25, 25, 192)          0         ['activation_662[0][0]']
#  ng2D)
#
#  conv2d_666 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_29[0][0]']
#
#  batch_normalization_666 (B  (None, 25, 25, 64)           192       ['conv2d_666[0][0]']
#  atchNormalization)
#
#  activation_666 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_666[0][0
#  )                                                                  ]']
#
#  conv2d_664 (Conv2D)         (None, 25, 25, 48)           9216      ['max_pooling2d_29[0][0]']
#
#  conv2d_667 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_666[0][0]']
#
#  batch_normalization_664 (B  (None, 25, 25, 48)           144       ['conv2d_664[0][0]']
#  atchNormalization)
#
#  batch_normalization_667 (B  (None, 25, 25, 96)           288       ['conv2d_667[0][0]']
#  atchNormalization)
#
#  activation_664 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_664[0][0
#  )                                                                  ]']
#
#  activation_667 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_667[0][0
#  )                                                                  ]']
#
#  average_pooling2d_63 (Aver  (None, 25, 25, 192)          0         ['max_pooling2d_29[0][0]']
#  agePooling2D)
#
#  conv2d_663 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_29[0][0]']
#
#  conv2d_665 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_664[0][0]']
#
#  conv2d_668 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_667[0][0]']
#
#  conv2d_669 (Conv2D)         (None, 25, 25, 32)           6144      ['average_pooling2d_63[0][0]']
#
#  batch_normalization_663 (B  (None, 25, 25, 64)           192       ['conv2d_663[0][0]']
#  atchNormalization)
#
#  batch_normalization_665 (B  (None, 25, 25, 64)           192       ['conv2d_665[0][0]']
#  atchNormalization)
#
#  batch_normalization_668 (B  (None, 25, 25, 96)           288       ['conv2d_668[0][0]']
#  atchNormalization)
#
#  batch_normalization_669 (B  (None, 25, 25, 32)           96        ['conv2d_669[0][0]']
#  atchNormalization)
#
#  activation_663 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_663[0][0
#  )                                                                  ]']
#
#  activation_665 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_665[0][0
#  )                                                                  ]']
#
#  activation_668 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_668[0][0
#  )                                                                  ]']
#
#  activation_669 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_669[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 25, 25, 256)          0         ['activation_663[0][0]',
#                                                                      'activation_665[0][0]',
#                                                                      'activation_668[0][0]',
#                                                                      'activation_669[0][0]']
#
#  conv2d_673 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_673 (B  (None, 25, 25, 64)           192       ['conv2d_673[0][0]']
#  atchNormalization)
#
#  activation_673 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_673[0][0
#  )                                                                  ]']
#
#  conv2d_671 (Conv2D)         (None, 25, 25, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_674 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_673[0][0]']
#
#  batch_normalization_671 (B  (None, 25, 25, 48)           144       ['conv2d_671[0][0]']
#  atchNormalization)
#
#  batch_normalization_674 (B  (None, 25, 25, 96)           288       ['conv2d_674[0][0]']
#  atchNormalization)
#
#  activation_671 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_671[0][0
#  )                                                                  ]']
#
#  activation_674 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_674[0][0
#  )                                                                  ]']
#
#  average_pooling2d_64 (Aver  (None, 25, 25, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_670 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_672 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_671[0][0]']
#
#  conv2d_675 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_674[0][0]']
#
#  conv2d_676 (Conv2D)         (None, 25, 25, 64)           16384     ['average_pooling2d_64[0][0]']
#
#  batch_normalization_670 (B  (None, 25, 25, 64)           192       ['conv2d_670[0][0]']
#  atchNormalization)
#
#  batch_normalization_672 (B  (None, 25, 25, 64)           192       ['conv2d_672[0][0]']
#  atchNormalization)
#
#  batch_normalization_675 (B  (None, 25, 25, 96)           288       ['conv2d_675[0][0]']
#  atchNormalization)
#
#  batch_normalization_676 (B  (None, 25, 25, 64)           192       ['conv2d_676[0][0]']
#  atchNormalization)
#
#  activation_670 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_670[0][0
#  )                                                                  ]']
#
#  activation_672 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_672[0][0
#  )                                                                  ]']
#
#  activation_675 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_675[0][0
#  )                                                                  ]']
#
#  activation_676 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_676[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 25, 25, 288)          0         ['activation_670[0][0]',
#                                                                      'activation_672[0][0]',
#                                                                      'activation_675[0][0]',
#                                                                      'activation_676[0][0]']
#
#  conv2d_680 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_680 (B  (None, 25, 25, 64)           192       ['conv2d_680[0][0]']
#  atchNormalization)
#
#  activation_680 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_680[0][0
#  )                                                                  ]']
#
#  conv2d_678 (Conv2D)         (None, 25, 25, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_681 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_680[0][0]']
#
#  batch_normalization_678 (B  (None, 25, 25, 48)           144       ['conv2d_678[0][0]']
#  atchNormalization)
#
#  batch_normalization_681 (B  (None, 25, 25, 96)           288       ['conv2d_681[0][0]']
#  atchNormalization)
#
#  activation_678 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_678[0][0
#  )                                                                  ]']
#
#  activation_681 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_681[0][0
#  )                                                                  ]']
#
#  average_pooling2d_65 (Aver  (None, 25, 25, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_677 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_679 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_678[0][0]']
#
#  conv2d_682 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_681[0][0]']
#
#  conv2d_683 (Conv2D)         (None, 25, 25, 64)           18432     ['average_pooling2d_65[0][0]']
#
#  batch_normalization_677 (B  (None, 25, 25, 64)           192       ['conv2d_677[0][0]']
#  atchNormalization)
#
#  batch_normalization_679 (B  (None, 25, 25, 64)           192       ['conv2d_679[0][0]']
#  atchNormalization)
#
#  batch_normalization_682 (B  (None, 25, 25, 96)           288       ['conv2d_682[0][0]']
#  atchNormalization)
#
#  batch_normalization_683 (B  (None, 25, 25, 64)           192       ['conv2d_683[0][0]']
#  atchNormalization)
#
#  activation_677 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_677[0][0
#  )                                                                  ]']
#
#  activation_679 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_679[0][0
#  )                                                                  ]']
#
#  activation_682 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_682[0][0
#  )                                                                  ]']
#
#  activation_683 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_683[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 25, 25, 288)          0         ['activation_677[0][0]',
#                                                                      'activation_679[0][0]',
#                                                                      'activation_682[0][0]',
#                                                                      'activation_683[0][0]']
#
#  conv2d_685 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_685 (B  (None, 25, 25, 64)           192       ['conv2d_685[0][0]']
#  atchNormalization)
#
#  activation_685 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_685[0][0
#  )                                                                  ]']
#
#  conv2d_686 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_685[0][0]']
#
#  batch_normalization_686 (B  (None, 25, 25, 96)           288       ['conv2d_686[0][0]']
#  atchNormalization)
#
#  activation_686 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_686[0][0
#  )                                                                  ]']
#
#  conv2d_684 (Conv2D)         (None, 12, 12, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_687 (Conv2D)         (None, 12, 12, 96)           82944     ['activation_686[0][0]']
#
#  batch_normalization_684 (B  (None, 12, 12, 384)          1152      ['conv2d_684[0][0]']
#  atchNormalization)
#
#  batch_normalization_687 (B  (None, 12, 12, 96)           288       ['conv2d_687[0][0]']
#  atchNormalization)
#
#  activation_684 (Activation  (None, 12, 12, 384)          0         ['batch_normalization_684[0][0
#  )                                                                  ]']
#
#  activation_687 (Activation  (None, 12, 12, 96)           0         ['batch_normalization_687[0][0
#  )                                                                  ]']
#
#  max_pooling2d_30 (MaxPooli  (None, 12, 12, 288)          0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 12, 12, 768)          0         ['activation_684[0][0]',
#                                                                      'activation_687[0][0]',
#                                                                      'max_pooling2d_30[0][0]']
#
#  conv2d_692 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_692 (B  (None, 12, 12, 128)          384       ['conv2d_692[0][0]']
#  atchNormalization)
#
#  activation_692 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_692[0][0
#  )                                                                  ]']
#
#  conv2d_693 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_692[0][0]']
#
#  batch_normalization_693 (B  (None, 12, 12, 128)          384       ['conv2d_693[0][0]']
#  atchNormalization)
#
#  activation_693 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_693[0][0
#  )                                                                  ]']
#
#  conv2d_689 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_694 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_693[0][0]']
#
#  batch_normalization_689 (B  (None, 12, 12, 128)          384       ['conv2d_689[0][0]']
#  atchNormalization)
#
#  batch_normalization_694 (B  (None, 12, 12, 128)          384       ['conv2d_694[0][0]']
#  atchNormalization)
#
#  activation_689 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_689[0][0
#  )                                                                  ]']
#
#  activation_694 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_694[0][0
#  )                                                                  ]']
#
#  conv2d_690 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_689[0][0]']
#
#  conv2d_695 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_694[0][0]']
#
#  batch_normalization_690 (B  (None, 12, 12, 128)          384       ['conv2d_690[0][0]']
#  atchNormalization)
#
#  batch_normalization_695 (B  (None, 12, 12, 128)          384       ['conv2d_695[0][0]']
#  atchNormalization)
#
#  activation_690 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_690[0][0
#  )                                                                  ]']
#
#  activation_695 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_695[0][0
#  )                                                                  ]']
#
#  average_pooling2d_66 (Aver  (None, 12, 12, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_688 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_691 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_690[0][0]']
#
#  conv2d_696 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_695[0][0]']
#
#  conv2d_697 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_66[0][0]']
#
#  batch_normalization_688 (B  (None, 12, 12, 192)          576       ['conv2d_688[0][0]']
#  atchNormalization)
#
#  batch_normalization_691 (B  (None, 12, 12, 192)          576       ['conv2d_691[0][0]']
#  atchNormalization)
#
#  batch_normalization_696 (B  (None, 12, 12, 192)          576       ['conv2d_696[0][0]']
#  atchNormalization)
#
#  batch_normalization_697 (B  (None, 12, 12, 192)          576       ['conv2d_697[0][0]']
#  atchNormalization)
#
#  activation_688 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_688[0][0
#  )                                                                  ]']
#
#  activation_691 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_691[0][0
#  )                                                                  ]']
#
#  activation_696 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_696[0][0
#  )                                                                  ]']
#
#  activation_697 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_697[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 12, 12, 768)          0         ['activation_688[0][0]',
#                                                                      'activation_691[0][0]',
#                                                                      'activation_696[0][0]',
#                                                                      'activation_697[0][0]']
#
#  conv2d_702 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_702 (B  (None, 12, 12, 160)          480       ['conv2d_702[0][0]']
#  atchNormalization)
#
#  activation_702 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_702[0][0
#  )                                                                  ]']
#
#  conv2d_703 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_702[0][0]']
#
#  batch_normalization_703 (B  (None, 12, 12, 160)          480       ['conv2d_703[0][0]']
#  atchNormalization)
#
#  activation_703 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_703[0][0
#  )                                                                  ]']
#
#  conv2d_699 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_704 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_703[0][0]']
#
#  batch_normalization_699 (B  (None, 12, 12, 160)          480       ['conv2d_699[0][0]']
#  atchNormalization)
#
#  batch_normalization_704 (B  (None, 12, 12, 160)          480       ['conv2d_704[0][0]']
#  atchNormalization)
#
#  activation_699 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_699[0][0
#  )                                                                  ]']
#
#  activation_704 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_704[0][0
#  )                                                                  ]']
#
#  conv2d_700 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_699[0][0]']
#
#  conv2d_705 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_704[0][0]']
#
#  batch_normalization_700 (B  (None, 12, 12, 160)          480       ['conv2d_700[0][0]']
#  atchNormalization)
#
#  batch_normalization_705 (B  (None, 12, 12, 160)          480       ['conv2d_705[0][0]']
#  atchNormalization)
#
#  activation_700 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_700[0][0
#  )                                                                  ]']
#
#  activation_705 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_705[0][0
#  )                                                                  ]']
#
#  average_pooling2d_67 (Aver  (None, 12, 12, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_698 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_701 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_700[0][0]']
#
#  conv2d_706 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_705[0][0]']
#
#  conv2d_707 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_67[0][0]']
#
#  batch_normalization_698 (B  (None, 12, 12, 192)          576       ['conv2d_698[0][0]']
#  atchNormalization)
#
#  batch_normalization_701 (B  (None, 12, 12, 192)          576       ['conv2d_701[0][0]']
#  atchNormalization)
#
#  batch_normalization_706 (B  (None, 12, 12, 192)          576       ['conv2d_706[0][0]']
#  atchNormalization)
#
#  batch_normalization_707 (B  (None, 12, 12, 192)          576       ['conv2d_707[0][0]']
#  atchNormalization)
#
#  activation_698 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_698[0][0
#  )                                                                  ]']
#
#  activation_701 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_701[0][0
#  )                                                                  ]']
#
#  activation_706 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_706[0][0
#  )                                                                  ]']
#
#  activation_707 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_707[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 12, 12, 768)          0         ['activation_698[0][0]',
#                                                                      'activation_701[0][0]',
#                                                                      'activation_706[0][0]',
#                                                                      'activation_707[0][0]']
#
#  conv2d_712 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_712 (B  (None, 12, 12, 160)          480       ['conv2d_712[0][0]']
#  atchNormalization)
#
#  activation_712 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_712[0][0
#  )                                                                  ]']
#
#  conv2d_713 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_712[0][0]']
#
#  batch_normalization_713 (B  (None, 12, 12, 160)          480       ['conv2d_713[0][0]']
#  atchNormalization)
#
#  activation_713 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_713[0][0
#  )                                                                  ]']
#
#  conv2d_709 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_714 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_713[0][0]']
#
#  batch_normalization_709 (B  (None, 12, 12, 160)          480       ['conv2d_709[0][0]']
#  atchNormalization)
#
#  batch_normalization_714 (B  (None, 12, 12, 160)          480       ['conv2d_714[0][0]']
#  atchNormalization)
#
# ...
#  )                                                                  ]']
#
#  conv2d_736 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_735[0][0]']
#
#  conv2d_737 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_735[0][0]']
#
#  conv2d_740 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_739[0][0]']
#
#  conv2d_741 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_739[0][0]']
#
#  average_pooling2d_70 (Aver  (None, 5, 5, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_734 (Conv2D)         (None, 5, 5, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_736 (B  (None, 5, 5, 384)            1152      ['conv2d_736[0][0]']
#  atchNormalization)
#
#  batch_normalization_737 (B  (None, 5, 5, 384)            1152      ['conv2d_737[0][0]']
#  atchNormalization)
#
#  batch_normalization_740 (B  (None, 5, 5, 384)            1152      ['conv2d_740[0][0]']
#  atchNormalization)
#
#  batch_normalization_741 (B  (None, 5, 5, 384)            1152      ['conv2d_741[0][0]']
#  atchNormalization)
#
#  conv2d_742 (Conv2D)         (None, 5, 5, 192)            245760    ['average_pooling2d_70[0][0]']
#
#  batch_normalization_734 (B  (None, 5, 5, 320)            960       ['conv2d_734[0][0]']
#  atchNormalization)
#
#  activation_736 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_736[0][0
#  )                                                                  ]']
#
#  activation_737 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_737[0][0
#  )                                                                  ]']
#
#  activation_740 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_740[0][0
#  )                                                                  ]']
#
#  activation_741 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_741[0][0
#  )                                                                  ]']
#
#  batch_normalization_742 (B  (None, 5, 5, 192)            576       ['conv2d_742[0][0]']
#  atchNormalization)
#
#  activation_734 (Activation  (None, 5, 5, 320)            0         ['batch_normalization_734[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 5, 5, 768)            0         ['activation_736[0][0]',
#                                                                      'activation_737[0][0]']
#
#  concatenate_14 (Concatenat  (None, 5, 5, 768)            0         ['activation_740[0][0]',
#  e)                                                                  'activation_741[0][0]']
#
#  activation_742 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_742[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 5, 5, 2048)           0         ['activation_734[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_14[0][0]',
#                                                                      'activation_742[0][0]']
#
#  conv2d_747 (Conv2D)         (None, 5, 5, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_747 (B  (None, 5, 5, 448)            1344      ['conv2d_747[0][0]']
#  atchNormalization)
#
#  activation_747 (Activation  (None, 5, 5, 448)            0         ['batch_normalization_747[0][0
#  )                                                                  ]']
#
#  conv2d_744 (Conv2D)         (None, 5, 5, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_748 (Conv2D)         (None, 5, 5, 384)            1548288   ['activation_747[0][0]']
#
#  batch_normalization_744 (B  (None, 5, 5, 384)            1152      ['conv2d_744[0][0]']
#  atchNormalization)
#
#  batch_normalization_748 (B  (None, 5, 5, 384)            1152      ['conv2d_748[0][0]']
#  atchNormalization)
#
#  activation_744 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_744[0][0
#  )                                                                  ]']
#
#  activation_748 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_748[0][0
#  )                                                                  ]']
#
#  conv2d_745 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_744[0][0]']
#
#  conv2d_746 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_744[0][0]']
#
#  conv2d_749 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_748[0][0]']
#
#  conv2d_750 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_748[0][0]']
#
#  average_pooling2d_71 (Aver  (None, 5, 5, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_743 (Conv2D)         (None, 5, 5, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_745 (B  (None, 5, 5, 384)            1152      ['conv2d_745[0][0]']
#  atchNormalization)
#
#  batch_normalization_746 (B  (None, 5, 5, 384)            1152      ['conv2d_746[0][0]']
#  atchNormalization)
#
#  batch_normalization_749 (B  (None, 5, 5, 384)            1152      ['conv2d_749[0][0]']
#  atchNormalization)
#
#  batch_normalization_750 (B  (None, 5, 5, 384)            1152      ['conv2d_750[0][0]']
#  atchNormalization)
#
#  conv2d_751 (Conv2D)         (None, 5, 5, 192)            393216    ['average_pooling2d_71[0][0]']
#
#  batch_normalization_743 (B  (None, 5, 5, 320)            960       ['conv2d_743[0][0]']
#  atchNormalization)
#
#  activation_745 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_745[0][0
#  )                                                                  ]']
#
#  activation_746 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_746[0][0
#  )                                                                  ]']
#
#  activation_749 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_749[0][0
#  )                                                                  ]']
#
#  activation_750 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_750[0][0
#  )                                                                  ]']
#
#  batch_normalization_751 (B  (None, 5, 5, 192)            576       ['conv2d_751[0][0]']
#  atchNormalization)
#
#  activation_743 (Activation  (None, 5, 5, 320)            0         ['batch_normalization_743[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 5, 5, 768)            0         ['activation_745[0][0]',
#                                                                      'activation_746[0][0]']
#
#  concatenate_15 (Concatenat  (None, 5, 5, 768)            0         ['activation_749[0][0]',
#  e)                                                                  'activation_750[0][0]']
#
#  activation_751 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_751[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 5, 5, 2048)           0         ['activation_743[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_15[0][0]',
#                                                                      'activation_751[0][0]']
#
#  global_average_pooling2d_5  (None, 2048)                 0         ['mixed10[0][0]']
#   (GlobalAveragePooling2D)
#
#  new_dense_1 (Dense)         (None, 128)                  262272    ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  new_output (Dense)          (None, 4)                    516       ['new_dense_1[0][0]']
#
# ==================================================================================================
# Total params: 22065572 (84.17 MB)
# Trainable params: 262788 (1.00 MB)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# #####**3.2 VGG19**

# %%
class VGG19Model(PretrainedModel):
    def __init__(self):
        super().__init__()

    def load_base_model(self):
        super().load_base_model(VGG19)

    def create_final_model(self):
        self.freeze_layers()

        last_output = self.base_model.output
        x = tf.keras.layers.GlobalAveragePooling2D()(last_output)
        x = tf.keras.layers.Dense(128, activation='relu', name='new_dense_1')(x)
        x = tf.keras.layers.Dense(4, activation='softmax',name='new_output')(x)

        self.model = tf.keras.models.Model(inputs=self.base_model.input, outputs=x)

        self.model.compile(optimizer='adam', loss='categorical_crossentropy',
                  metrics=['categorical_accuracy'])

# %%
vgg_model = VGG19Model()
vgg_model.load_base_model()
vgg_model.create_final_model()
vgg_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 3s 0us/step
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d_6  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  new_dense_1 (Dense)         (None, 128)               65664
#
#  new_output (Dense)          (None, 4)                 516
#
# =================================================================
# Total params: 20090564 (76.64 MB)
# Trainable params: 66180 (258.52 KB)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________
